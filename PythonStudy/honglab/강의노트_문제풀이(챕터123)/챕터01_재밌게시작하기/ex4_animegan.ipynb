# %% [markdown]
# ___
# <a href='https://cafe.naver.com/jmhonglab'><p style="text-align:center;"><img src='https://lh3.googleusercontent.com/lY3ySXooSmwsq5r-mRi7uiypbo0Vez6pmNoQxMFhl9fmZJkRHu5lO2vo7se_0YOzgmDyJif9fi4_z0o3ZFdwd8NVSWG6Ea80uWaf3pOHpR4GHGDV7kaFeuHR3yAjIJjDgfXMxsvw=w2400'  class="center" width="50%" height="50%"/></p></a>
# ___
# <center><em>Content Copyright by HongLab, Inc.</em></center>

# %% [markdown]
# # 인공지능도 쉽게 사용할 수 있어요
#
# [AnimeGAN v2 파이토치 구현](https://github.com/bryandlee/animegan2-pytorch)을 사용하기 편하도록 정리한 예제입니다.

# %% [markdown]
# ### 콘다(conda)로 가상환경 만들기
#
# 윈도우에서는 powershell에서 conda를 초기화 해줘야 합니다. 참고로 Anaconda Prompt에서는 이미 초기화가 되어 있습니다.
# > conda init powershell
#
# 가상환경을 만들어줍니다.
# > conda create -n my_env python=3.8
#
# 가상환경을 활성화시켜줍니다.
# > conda activate my_env
#
# 가상환경에서 나올 수도 있습니다. (비활성화)
# > conda deactivate my_env
#
# 새로 만든 가상환경 안에서 [Pytorch](https://pytorch.org/)를 설치해봅시다.

# %% [markdown]
# ### 내 얼굴 사진을 애니메이션 캐릭터로 바꿔봐요
#
# 딥러닝에서 사용되는 인공지능을 훈련시킬때는 빠른 GPU가 필요하지만 훈련이 끝난 후에는 CPU에서도 꽤 빠르게 작동합니다.

# %%
from PIL import Image

img = Image.open("jun.jpg").convert("RGB")

display(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1050x1350 at 0x7FDC71427640>

# %%
import torch


def run(img, pretrained):
    model = torch.hub.load(
        "bryandlee/animegan2-pytorch:main", "generator", pretrained=pretrained
    )
    face2paint = torch.hub.load(
        "bryandlee/animegan2-pytorch:main", "face2paint", size=512
    )
    out = face2paint(model, img)
    display(out)

# %%
model = torch.hub.load("bryandlee/animegan2-pytorch:main", "generator", pretrained="celeba_distill")
model = torch.hub.load("bryandlee/animegan2-pytorch:main", "generator", pretrained="face_paint_512_v1")
model = torch.hub.load("bryandlee/animegan2-pytorch:main", "generator", pretrained="face_paint_512_v2")
model = torch.hub.load("bryandlee/animegan2-pytorch:main", "generator", pretrained="paprika")
# Out:
# Using cache found in /Users/seojunyoo/.cache/torch/hub/bryandlee_animegan2-pytorch_main
# Using cache found in /Users/seojunyoo/.cache/torch/hub/bryandlee_animegan2-pytorch_main
# Using cache found in /Users/seojunyoo/.cache/torch/hub/bryandlee_animegan2-pytorch_main
# Using cache found in /Users/seojunyoo/.cache/torch/hub/bryandlee_animegan2-pytorch_main

# %%
run(img, "celeba_distill")
# Out:
# Using cache found in /Users/seojunyoo/.cache/torch/hub/bryandlee_animegan2-pytorch_main
# Using cache found in /Users/seojunyoo/.cache/torch/hub/bryandlee_animegan2-pytorch_main
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FDC91D8C790>

# %%
run(img, "face_paint_512_v1")
# Out:
# Using cache found in /Users/seojunyoo/.cache/torch/hub/bryandlee_animegan2-pytorch_main
# Downloading: "https://github.com/bryandlee/animegan2-pytorch/raw/main/weights/face_paint_512_v1.pt" to /Users/seojunyoo/.cache/torch/hub/checkpoints/face_paint_512_v1.pt
#   0%|          | 0.00/8.20M [00:00<?, ?B/s]
# Using cache found in /Users/seojunyoo/.cache/torch/hub/bryandlee_animegan2-pytorch_main
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FDC91474E80>

# %%
run(img, "face_paint_512_v2")
# Out:
# Using cache found in /Users/seojunyoo/.cache/torch/hub/bryandlee_animegan2-pytorch_main
# Using cache found in /Users/seojunyoo/.cache/torch/hub/bryandlee_animegan2-pytorch_main
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FDC914882B0>

# %%
run(img, "paprika")
# Out:
# Using cache found in /Users/seojunyoo/.cache/torch/hub/bryandlee_animegan2-pytorch_main
# Using cache found in /Users/seojunyoo/.cache/torch/hub/bryandlee_animegan2-pytorch_main
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FDC91472100>

# %% [markdown]
# ### 사진을 바꿔서 해보세요. 얼굴이 크게 나온 사진이 더 잘 됩니다.
